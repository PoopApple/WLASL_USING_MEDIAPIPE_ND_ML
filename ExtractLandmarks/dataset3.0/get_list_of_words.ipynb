# %%
import string
import os
import spacy
import wordninja

# %%
nlp = spacy.load("en_core_web_sm")

def split_compound(word):
    parts = wordninja.split(word)
    return parts if parts else [word]

def lemmatize(word):
    parts = split_compound(word)
    lemmatised_parts = []
    for part in parts:
        doc = nlp(part)
        lemmatised_parts.append(doc[0].lemma_)
    return "_".join(lemmatised_parts)

# %%
datasetpath = "./landmarks_npz"

# %%
print(len(os.listdir(datasetpath)))
# Out:
# 2731

# %%
wordlist = os.listdir(datasetpath)

og_clean_wordlist = {word : word.rstrip(string.digits).replace(".","").lower() for word in wordlist}

# print(wordlist)

# %%
print(len(og_clean_wordlist))
# Out:
# 2731

# %%
print(og_clean_wordlist['ABSOLUTELYNOTHING'])
# Out:
# absolutelynothing

# %%
lemmatisedwords = {og_word : lemmatize(clean_word) for og_word,clean_word in og_clean_wordlist.items()}

# lemmatisedwords = {word:lemmatize(word) for word in wordlist}
with open("./dataset3_words_lemmatised.txt","w") as f:
    for k,v in lemmatisedwords.items():
        f.write(f"{v}\n")
    
dataset_words_lemmatised = lemmatisedwords.values()

print(len(dataset_words_lemmatised))
# Out:
# 2731

# %%
#TEST

import spacy
nlp = spacy.load("en_core_web_sm")

word = "ABSOLUTELYNOTHING"
doc = nlp(word)

for token in doc:
    print(token.text, "->", token.lemma_)
# Out:
# ABSOLUTELYNOTHING -> absolutelynothe
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(lemmatisedwords['ABSOLUTELYNOTHING'])
# Out:
# absolutely_nothing

# %%
set_of_dataset_words = set(dataset_words_lemmatised)

print(len(set_of_dataset_words))
print(len(dataset_words_lemmatised))
# Out:
# 2273
# 2731

# %%
clean_oglist = {}

for og,lem in lemmatisedwords.items():
    if clean_oglist.get(lem):
        clean_oglist[lem].append(og)
    else:
        clean_oglist[lem] = [og]


for x,y in sorted(clean_oglist.items()):
    print(f"{x} => {",".join(y)}")
# Out:
# 1_dollar => 1DOLLAR
# 5_dollar => 5DOLLARS
# 8_hour => 8HOUR
# 9_o_clock => 9OCLOCK
# I => ME
# I_a_culpa => MEACULPA
# a_line_bob => A-LINEBOB
# a_little_bit => ALITTLEBIT
# abbreviate => ABBREVIATE
# about => ABOUT2,ABOUT1
# above => ABOVE
# absolutely_nothing => ABSOLUTELYNOTHING
# accent => ACCENT
# accept => ACCEPT
# access => ACCESS
# accident => ACCIDENT
# accomplish => ACCOMPLISH
# accordion => ACCORDION
# accountant => ACCOUNTANT
# acquire => ACQUIRE
# act => ACT
# action => ACTION
# actor => ACTOR
# add => ADD
# addict => ADDICT
# address => ADDRESS
# admire => ADMIRE
# admit => ADMIT
# adopt => ADOPT
# adult => ADULT
# advantage => ADVANTAGE
# advertise => ADVERTISE
# africa => AFRICA
# after => AFTER
# afternoon => AFTERNOON
# again => AGAIN
# against => AGAINST
# age => AGE
# agency => AGENCY
# agreement => AGREEMENT
# airplane => AIRPLANE
# alarm => ALARM
# alaska => ALASKA
# alcohol => ALCOHOL
# align => ALIGN
# all => ALL
# all_day => ALLDAY
# all_go => ALLGONE
# all_of_sudden => ALLOFSUDDEN
# all_over => ALLOVER
# all_over_body => ALLOVERBODY
# all_way => ALLWAY
# alltogether => ALLTOGETHER
# alone => ALONE
# alphabet => ALPHABET
# alright => ALRIGHT
# always => ALWAYS
# amazing => AMAZING
# america => AMERICA
# analyze => ANALYZE
# and => AND
# angel => ANGEL
# angry => ANGRY
# animal => ANIMAL
# announce => ANNOUNCE
# answer => ANSWER
# antler => ANTLERS
# any => ANY
# anyone => ANYONE
# apart => APART
# appear => APPEAR
# apple => APPLE
# appointment => APPOINTMENT
# april => APRIL
# archeology => ARCHEOLOGY
# area => AREA
# argue => ARGUE
# arizona => ARIZONA
# arm => ARM2,ARM1,ARM3
# army => ARMY
# arrest => ARREST2,ARREST1,ARREST3
# arrive => ARRIVE
# art => ART
# article => ARTICLE
# articulate_sign => ARTICULATESIGN
# asia => ASIA
# ask => ASK
# assembly => ASSEMBLY
# assign => ASSIGN
# assist => ASSIST
# assistant => ASSISTANT
# astronaut => ASTRONAUT
# at => AT
# athlete => ATHLETE
# atlanta => ATLANTA
# attention => ATTENTION
# attitude => ATTITUDE
# audience => AUDIENCE
# auditorium => AUDITORIUM
# aunt => AUNT
# australia => AUSTRALIA
# autism => AUTISM2,AUTISM1
# automatic => AUTOMATIC
# average => AVERAGE
# avoid => AVOID
# awake => AWAKE
# award => AWARD
# away => AWAY
# awkward => AWKWARD
# axe => AXE1,AXE2
# baby => BABY1,BABY2
# babysitter => BABYSITTER
# bachelor => BACHELOR
# back => BACK
# back_out => BACKOUT
# backpack => BACKPACK2,BACKPACK1
# backup => BACKUP
# backyard => BACKYARD
# bacon => BACON
# bad => WORSE,BAD
# badge => BADGE
# bag => BAG2,BAG1
# bake => BAKE2,BAKE1
# balance => BALANCE
# bald => BALD
# ball => BALL
# balloon => BALLOON
# banana => BANANA1,BANANA4,BANANA3,BANANA2
# band_aid => BANDAID1,BANDAID2
# bandage => BANDAGE
# bank => BANK
# bar => BAR
# barely => BARELY
# bark => BARK3,BARK2,BARK1
# barrette => BARRETTE
# baseball => BASEBALL
# baseball_cap => BASEBALLCAP
# basement => BASEMENT
# basic => BASIC
# basket => BASKET2,BASKET1
# basketball => BASKETBALL3,BASKETBALL2,BASKETBALL1
# bat => BAT1,BAT2,BAT3
# bath => BATH
# bathroom => BATHROOM
# bathtub => BATHTUB
# battery => BATTERY
# beach => BEACH
# beak => BEAK
# bean => BEANS
# beanie => BEANIE
# bear => BEAR
# beard => BEARD
# beat => BEAT
# beaver => BEAVER
# because => BECAUSE
# become => BECOME
# bed => BED1,BED2
# bedroom => BEDROOM
# bee => BEE2,BEE1
# beer => BEER
# before => BEFORE
# beg => BEG
# behavior => BEHAVIOR
# behind => BEHIND
# believe => BELIEVE2,BELIEVE1
# bell => BELL
# belt => BELT1,BELT2
# bend => BEND
# benefit => BENEFIT
# berry => BERRY
# bet => BET
# between => BETWEEN
# bib => BIB
# bicycle => BICYCLE
# big => BIG
# bind => BIND
# binocular => BINOCULARS
# biology => BIOLOGY
# bird => BIRD
# birth => BIRTH
# birthday => BIRTHDAY
# bison => BISON
# bitch => BITCH
# bite => BITE1,BITE2
# bite_on_arm => BITEONARM
# bite_on_neck => BITEONNECK
# black => BLACK
# blackbird => BLACKBIRD
# blame => BLAME
# blank => BLANK
# blanket => BLANKET
# bleed => BLEED
# bless => BLESS
# blind => BLINDS1,BLIND,BLINDS2
# blink => BLINK
# blond => BLOND
# blood => BLOOD
# bloom => BLOOM
# blouse => BLOUSE
# blow => BLOW
# blow_candle => BLOWCANDLE2,BLOWCANDLE1
# blow_mind => BLOWMIND
# blue => BLUE
# blur => BLUR
# blush => BLUSH
# board => BOARD
# boat => BOAT
# body => BODY
# boil => BOIL2,BOIL1
# boil_mad => BOILINGMAD
# bolt => BOLT
# bomb => BOMB
# bone => BONE
# book => BOOK
# boot => BOOTS1,BOOTS2
# bore => BORED2,BORED1
# borrow => BORROW
# boss => BOSS
# boston => BOSTON
# both => BOTH
# bother => BOTHER
# bottle => BOTTLE
# bottom => BOTTOM
# bounce => BOUNCE
# bow => BOW4,BOW2,BOW3,BOW1
# bow_tie => BOWTIE
# bowl => BOWLING2,BOWL,BOWLING1
# box => BOX,BOXING
# boy => BOY
# boyfriend => BOYFRIEND
# bra => BRA1,BRA3,BRA2
# bracelet => BRACELET
# brag => BRAG
# braid => BRAIDS
# braille => BRAILLE
# brainstorm => BRAINSTORM
# brainwash => BRAINWASH
# brave => BRAVE
# bread => BREAD
# break => BREAK
# break_time => BREAKTIME
# breakdown => BREAKDOWN2,BREAKDOWN1
# breakfast => BREAKFAST2,BREAKFAST1
# breathe => BREATHE
# brick => BRICK
# bridesmaid => BRIDESMAID
# bridge => BRIDGE2,BRIDGE1
# bright => BRIGHT
# bring => BRING
# brother => BROTHER
# brown => BROWN
# brush => BRUSH
# bubble => BUBBLES
# buckle => BUCKLE2,BUCKLE1
# budget => BUDGET
# buffalo => BUFFALO
# bug => BUG
# build => BUILDING
# bull => BULL
# bulldozer => BULLDOZER
# bullshit => BULLSHIT
# bumpy => BUMPY
# bun => BUN
# burn => BURN
# burp => BURP
# bury => BURY4,BURY1,BURY3,BURY2
# bus => BUS
# business => BUSINESS
# bust => BUSTED
# busy => BUSY
# but => BUT
# butter => BUTTER
# butterfly => BUTTERFLY
# button => BUTTONS
# buy => BUY
# bye => BYE
# cabinet => CABINET
# cafeteria => CAFETERIA
# cake => CAKE
# calculator => CALCULATOR
# calendar => CALENDAR1,CALENDAR2
# california => CALIFORNIA
# call => CALL2,CALL1
# call_attention => CALLATTENTION
# call_tty => CALLTTY
# calm => CALM
# camcorder => CAMCORDER
# camel => CAMEL
# camera => CAMERA
# cameraman => CAMERAMAN
# camping => CAMPING
# can => CAN1,CANNOT,CAN2
# canada => CANADA
# cancel => CANCEL1,CANCEL2
# cancellation => CANCELLATION
# cancer => CANCER1,CANCER2
# candle => CANDLE
# candy => CANDY1,CANDY2
# cannon => CANNON
# canoe => CANOE
# cape => CAPE
# caption => CAPTION
# capture => CAPTURE
# car => CAR
# car_accident => CARACCIDENT
# car_battery => CARBATTERY
# card => CARDS
# careful => CAREFUL
# carousel => CAROUSEL
# carrot => CARROT3,CARROT2,CARROT1
# carry => CARRY
# carve => CARVE
# castle => CASTLE2,CASTLE4,CASTLE1,CASTLE3
# casual => CASUAL
# cat => CAT1,CAT2,CAT3
# catapult => CATAPULT
# catch => CATCH2,CAUGHT,CATCH3,CATCH1
# catch_baseball => CATCHBASEBALL
# cate_pillar => CATEPILLAR
# category => CATEGORY
# catholic => CATHOLIC
# cause => CAUSE
# ceiling => CEILING
# celebrate => CELEBRATE
# celery => CELERY
# cellphone => CELLPHONE
# cemetery => CEMETERY
# center => CENTER
# cereal => CEREAL
# certificate => CERTIFICATE
# chain => CHAIN
# chair => CHAIR
# challenge => CHALLENGE
# champ => CHAMP
# champion => CHAMPION
# chance => CHANCE
# change => CHANGE
# channel => CHANNEL
# chaos => CHAOS
# character => CHARACTER
# charge => CHARGE
# charge_card => CHARGECARD
# chase => CHASE
# chat => CHAT
# cheap => CHEAP
# cheat => CHEAT2,CHEAT1
# check => CHECK
# cheek => CHEEK
# cheer => CHEER
# cheerleader => CHEERLEADER1,CHEERLEADER2
# cheese => CHEESE
# cheese_grater => CHEESEGRATER
# cherish => CHERISH
# cherry => CHERRY1,CHERRY2
# chew => CHEW3,CHEW4,CHEW1,CHEW2
# chew_2_mouth => CHEW2MOUTH
# chicago => CHICAGO
# child => CHILD,CHILDREN
# chimney => CHIMNEY
# chin => CHIN
# china => CHINA
# chocolate => CHOCOLATE
# choke => CHOKE
# chop => CHOP
# chopsticks => CHOPSTICKS
# christmas => CHRISTMAS1,CHRISTMAS2
# church => CHURCH
# churn => CHURN
# cigar => CIGAR
# cigarette => CIGARETTE
# circle => CIRCLE
# circus_wheel => CIRCUSWHEEL
# city => CITY2,CITY1
# clap => CLAP
# clash => CLASH
# class => CLASS
# clause => CLAUSE
# claw => CLAW
# clean => CLEAN
# clear => CLEAR
# cleft_chin => CLEFTCHIN
# click => CLICK
# client => CLIENT
# climb_ladder => CLIMBLADDER
# clip => CLIP
# clock => CLOCK1,CLOCK2
# close => CLOSE
# close_door => CLOSEDOOR
# close_eye => CLOSEEYES
# closet => CLOSET2,CLOSET1
# clothe => CLOTHES
# cloud => CLOUD4,CLOUD3,CLOUD2,CLOUD1
# clown => CLOWN
# clueless => CLUELESS
# coach => COACH
# coca_cola => COCACOLA
# cocaine => COCAINE
# coconut => COCONUT
# coffee => COFFEE
# coin => COINS
# cold => COLD
# college => COLLEGE
# color => COLOR
# comb => COMB2,COMB1
# come => COME
# come_here => COMEHERE
# come_out => COMEOUT
# comfortable => COMFORTABLE
# comment => COMMENT
# committee => COMMITTEE
# communication => COMMUNICATION
# community => COMMUNITY
# commute => COMMUTE
# compass => COMPASS
# complain => COMPLAIN
# complex => COMPLEX
# computer => COMPUTER
# computer_mouse => COMPUTERMOUSE
# concept => CONCEPT
# concern => CONCERNED
# conduct => CONDUCT3,CONDUCT1,CONDUCT2
# confident => CONFIDENT
# confidential => CONFIDENTIAL
# conflict => CONFLICT
# confuse => CONFUSED2,CONFUSED1
# congratulation => CONGRATULATIONS
# connection => CONNECTION
# consume => CONSUME
# contact => CONTACT
# contact_len => CONTACTLENS
# continue => CONTINUE
# convince => CONVINCE2,CONVINCE1
# cook => COOK
# cookie => COOKIE
# cool => COOL1,COOL4,COOL2,COOL3
# cooperate => COOPERATE
# copy => COPY
# corkscrew => CORKSCREW1,CORKSCREW2
# corn => CORN2,CORN1,CORN3
# corner => CORNER
# cost => COST
# couch => COUCH
# cough => COUGH
# counselor => COUNSELOR
# count => COUNT
# country => COUNTRY
# cousin => COUSIN
# cover_up => COVERUP
# cow => COW
# cowboy => COWBOY
# crack => CRACK
# cracker => CRACKER2,CRACKER1
# cranky => CRANKY
# crash => CRASH
# crash_plane => CRASHPLANE
# crawl => CRAWL2,CRAWL1
# crazy => CRAZY
# cream => CREAM1,CREAM2
# create => CREATE
# credit_card => CREDITCARD
# crew_cut => CREWCUT
# crocodile => CROCODILE
# cross => CROSS3,CROSS2,CROSS1
# cross_heart => CROSSHEART
# crown => CROWN
# crumple => CRUMPLE
# cry => CRY1,CRY2,CRY3,CRY4
# culture => CULTURE
# cup => CUP
# curious => CURIOUS
# curl => CURL1,CURL2
# curly_hair => CURLYHAIR
# curtain => CURTAIN
# curtsey => CURTSEY2,CURTSEY1
# cut => CUT
# cut_remove_vid => CUTREMOVEVID
# cute => CUTE2,CUTE1
# damn => DAMN
# dance => DANCE
# dancer => DANCER
# danger => DANGER
# dark => DARK1,DARK2
# dart => DART
# date => DATE
# daughter => DAUGHTER
# day => DAY
# deaf => DEAF1,DEAF2
# deaf_school => DEAFSCHOOL
# deal_card => DEALCARDS
# death => DEATH
# decide => DECIDE2,DECIDE1
# decline => DECLINE
# decorate => DECORATE2,DECORATE1
# dedicate => DEDICATE1,DEDICATE2
# deep => DEEP
# deer => DEER
# defeat => DEFEAT
# deflate => DEFLATE
# degree => DEGREE
# delegate => DELEGATE
# deliberate => DELIBERATE
# delicious => DELICIOUS
# delinquent => DELINQUENT
# demand => DEMAND2,DEMAND1
# demote => DEMOTE
# dent => DENT
# dentist => DENTIST2,DENTIST1
# deny => DENY
# deodorant => DEODORANT
# department => DEPARTMENT
# depend_on => DEPENDON
# depress => DEPRESS
# depth => DEPTH
# desert => DESERT
# design => DESIGN
# dessert => DESSERT
# destroy => DESTROY
# develop => DEVELOP2,DEVELOP1
# devil => DEVIL
# devour => DEVOUR
# diamond => DIAMOND
# diaper => DIAPER
# dice => DICE
# dictionary => DICTIONARY
# die => DIE
# different => DIFFERENT
# different_situation => DIFFERENTSITUATION
# dig => DIG
# dig_up => DIGUP
# dilemma => DILEMMA
# dining_room => DININGROOM
# dinner => DINNER2,DINNER1
# dinosaur => DINOSAUR1,DINOSAUR2
# dip => DIP3,DIP1,DIP2
# director => DIRECTOR
# dirty => DIRTY
# disagreement => DISAGREEMENT
# disappear => DISAPPEAR
# disappoint => DISAPPOINT
# disconnect => DISCONNECT
# discuss => DISCUSS
# dislike => DISLIKE
# disney => DISNEY
# dispatch => DISPATCH
# disrupt => DISRUPT
# dissect => DISSECT
# dissolve => DISSOLVE
# distract => DISTRACTED
# dive => DIVE
# divide => DIVIDE
# divorce => DIVORCE
# dizzy => DIZZY
# do_care => DONTCARE
# do_feel_like => DONTFEELLIKE
# do_know => DONTKNOW
# do_like => DONTLIKE
# do_matter => DOESNTMATTER
# do_mind => DONTMIND
# do_need => DONTNEED
# do_want => DONTWANT
# doctor => DOCTOR2,DOCTOR1
# document => DOCUMENT
# dodo => DODO
# dog => DOG2,DOG1,DOG3,DOG4
# doll => DOLL
# dolphin => DOLPHIN2,DOLPHIN1,DOLPHIN3
# dominant => DOMINANT
# donkey => DONKEY
# donut => DONUT
# door => DOOR
# dormitory => DORMITORY
# double => DOUBLE
# doubt => DOUBT
# down => DOWN
# downhill => DOWNHILL
# download => DOWNLOAD
# downsize => DOWNSIZE2,DOWNSIZE1
# drag => DRAG1,DRAG2
# dragon => DRAGON
# draw => DRAW
# drawer => DRAWER
# dreadlock => DREADLOCKS
# dream => DREAM
# dress => DRESS
# dresser => DRESSER
# dressup => DRESSUP
# dribble => DRIBBLE
# drill => DRILL
# drink => DRINK2,DRINK1
# drip => DRIP
# drive => DRIVE
# drop => DROP
# drown => DROWN4,DROWN1,DROWN5,DROWN3,DROWN2
# drug => DRUG
# drum => DRUM
# drunk => DRUNK
# dry => DRY
# dryer => DRYER
# duck => DUCK1,DUCK2
# due => DUE
# dumb => DUMB
# duty => DUTY
# dye => DYE
# each => EACH
# each_other => EACHOTHER
# eagle => EAGLE1,EAGLE2
# ear => EAR
# ear_up => EARSUP
# early => EARLY
# earmuff => EARMUFFS
# earn => EARN
# earring => EARRING
# earth => EARTH
# earthquake => EARTHQUAKE
# easel => EASEL
# east => EAST
# easter => EASTER
# easy => EASY
# easy_to_do => EASYTODO
# eat => EAT1,EAT2
# eclipse => ECLIPSE
# edge => EDGE
# edit => EDIT1,EDIT2
# effect => EFFECT
# egg => EGG
# eggbeater => EGGBEATER
# ego => EGO
# egypt => EGYPT
# eight => EIGHT
# either => EITHER
# electrician => ELECTRICIAN
# electrocute => ELECTROCUTE
# elegance => ELEGANCE
# elementary_school => ELEMENTARYSCHOOL
# elephant => ELEPHANT
# elevator => ELEVATOR1,ELEVATOR3,ELEVATOR2
# eleven => ELEVEN
# email => EMAIL
# embarrass => EMBARRASS
# emotion => EMOTION
# emperor => EMPEROR
# emphasis => EMPHASIS
# empty => EMPTY1,EMPTY2
# end => END
# enemy => ENEMY
# energy => ENERGY
# engagement => ENGAGEMENT
# engine_start => ENGINESTART
# engineer => ENGINEER
# english => ENGLISH
# enjoy => ENJOY
# enough => ENOUGH
# enter => ENTER
# envelope => ENVELOPE2,ENVELOPE3,ENVELOPE4,ENVELOPE5,ENVELOPE1
# environment => ENVIRONMENT
# equal => EQUAL
# erase => ERASE3,ERASE4,ERASE1,ERASE2,ERASE5
# eraser => ERASER
# erupt => ERUPT2,ERUPT1
# escalate => ESCALATE
# escalator => ESCALATOR
# escape => ESCAPE
# europe => EUROPE
# evaluate => EVALUATE
# even => EVEN
# event => EVENT
# every_night => EVERYNIGHT
# every_year => EVERYYEAR
# everyday => EVERYDAY
# everything => EVERYTHING
# evidence => EVIDENCE
# example => EXAMPLE
# excite => EXCITED
# excuse => EXCUSE
# exercise => EXERCISE
# expect => EXPECT
# expensive => EXPENSIVE
# experience => EXPERIENCED,EXPERIENCE
# experiment => EXPERIMENT
# expert => EXPERT
# explanation => EXPLANATION
# explode => EXPLODE
# express => EXPRESS
# eye => EYES
# eye_awake => EYESAWAKE
# eye_turn => EYETURN
# eyeglass => EYEGLASSES
# face => FACE
# faculty => FACULTY
# fade => FADE
# fail => FAIL
# faint => FAINT
# fair => FAIR
# fake => FAKE
# fall => FALL1,FALL2
# fall_asleep => FALLINGASLEEP
# family => FAMILY
# famous => FAMOUS
# fan => FAN
# fantasy => FANTASY
# far => FAR
# farm => FARM
# fascinated => FASCINATED
# fashion => FASHION
# fast => FAST
# fat => FAT
# father => FATHER
# faucet => FAUCET
# fault => FAULT
# favorite => FAVORITE
# february => FEBRUARY
# feed => FEED2,FEED1
# feed_up => FEDUP
# feedback => FEEDBACK
# feel => FEEL
# fence => FENCE2,FENCE1,FENCING
# few => FEW
# fiance => FIANCE
# fifth => FIFTH
# fight => FIGHT
# figure => FIGURE
# file => FILE2,FILE1,FILE3
# fill_out => FILLOUT
# film => FILM
# filter => FILTER
# finally => FINALLY
# finance => FINANCE
# find => FIND
# fine => FINE2,FINE1
# finger => FINGER
# finger_cross => FINGERSCROSSED
# finger_spell => FINGERSPELL
# fingerspell => FINGERSPELLING
# finish => FINISH
# fins => FINS
# fire => FIRE,FIRED
# fire_truck => FIRETRUCK
# fireman => FIREMAN2,FIREMAN1
# first => FIRST
# fish => FISH
# fishing => FISHING1,FISHING2
# fit => FIT
# fix => FIX
# flag => FLAG2,FLAG1
# flashlight => FLASHLIGHT2,FLASHLIGHT3,FLASHLIGHT4,FLASHLIGHT1
# flip => FLIP
# flip_flop => FLIPFLOPS
# flip_switch => FLIPSWITCH
# float => FLOAT3,FLOAT2,FLOAT1
# floor => FLOOR
# flower => FLOWER
# flute => FLUTE
# fly => FLY
# focus => FOCUS
# fold => FOLD1,FOLD2
# follow => FOLLOW3,FOLLOW2,FOLLOW4,FOLLOW1
# fond => FOND
# fool => FOOL
# football => FOOTBALL
# for => FOR
# forbid => FORBID
# foreigner => FOREIGNER1,FOREIGNER2
# forest => FOREST
# forever => FOREVER1,FOREVER2
# forfeit => FORFEIT
# forgetful => FORGETFUL
# fork => FORK4,FORK1,FORK3,FORK2
# form => FORM
# former => FORMER
# foul => FOUL
# four => FOUR
# fourth => FOURTH
# fox => FOX
# fraction => FRACTION
# frame => FRAME
# france => FRANCE
# fraud => FRAUD
# freak_out => FREAKOUT
# freckle => FRECKLES
# free => FREE
# freedom => FREEDOM
# freeway => FREEWAY
# freeze => FREEZE
# french => FRENCH
# french_fry => FRENCHFRIES
# friday => FRIDAY
# friend => FRIEND
# friend_no_more => FRIENDSNOMORE1
# friendly => FRIENDLY
# fringe => FRINGE
# frisk => FRISK
# frog => FROG
# from => FROM
# from_the_non => FROMTHENON
# front => FRONT
# frown => FROWN1,FROWN2
# fruit => FRUIT
# frustrate => FRUSTRATE
# fry => FRY
# full => FULL
# fun => FUN
# function => FUNCTION
# funny => FUNNY
# furniture => FURNITURE
# future => FUTURE
# fuzzy => FUZZY
# gallaudet => GALLAUDET
# gamble => GAMBLE
# game => GAME
# garage => GARAGE
# garlic => GARLIC
# gas => GAS
# gate => GATE
# gate_close => GATECLOSE
# gay => GAY
# generation => GENERATION
# germany => GERMANY
# gesture => GESTURE
# get => GET
# get_cha => GOTCHA
# get_in_bed => GETINBED
# get_information_out_of => GETINFORMATIONOUTOF
# get_off => GETOFF
# get_through => GETTHROUGH
# get_together => GETTOGETHER
# ghost => GHOST
# gift => GIFT
# giraffe => GIRAFFE
# girl => GIRL
# give => GIVE
# give_up => GIVEUP
# glass => GLASS2,GLASS1,GLASSES,GLASS3
# glove => GLOVES4,GLOVE,GLOVES1,GLOVES2,GLOVES3
# glow => GLOW
# glue => GLUE1,GLUE2
# go => GO,GONE
# go_ahead => GOAHEAD
# go_back_and_forth => GOBACKANDFORTH
# go_through => GOTHROUGH
# go_through_a_hard_time => GOINGTHROUGHAHARDTIME
# goal => GOAL
# goat => GOAT
# goatee => GOATEE
# god => GOD
# gold => GOLD
# golf => GOLF
# good => GOOD
# goody_goody => GOODYGOODY
# goody_goody_shoe_opposite => GOODYGOODYSHOEOPPOSITE
# goosebump => GOOSEBUMPS
# gorilla => GORILLA
# gossip => GOSSIP
# goto_jail => GOTOJAIL
# government => GOVERNMENT
# grab => GRAB
# grade => GRADE
# graduate => GRADUATE
# graduate_school => GRADUATESCHOOL
# grammar => GRAMMAR
# grandfather => GRANDFATHER
# grandmother => GRANDMOTHER
# grandparent => GRANDPARENTS
# grape => GRAPES2,GRAPES1
# grasp => GRASP
# grass => GRASS
# gray => GRAY
# great => GREAT
# greece => GREECE
# green => GREEN
# green_bean => GREENBEANS
# greet => GREET2,GREET1
# grenade => GRENADE
# grieve => GRIEVE
# grind => GRIND
# group => GROUP
# grow => GROW
# grow_up => GROWUP
# guess => GUESS2,GUESS1
# guide => GUIDE
# guillotine => GUILLOTINE2,GUILLOTINE1
# guilty => GUILTY
# guitar => GUITAR
# gullible => GULLIBLE
# gum => GUM
# gun => GUN1,GUN2,GUN3
# gym => GYM
# habit => HABIT
# hah_a => HAHA
# hair => HAIR2,HAIR1
# hair_clipper => HAIRCLIPPER
# hair_dryer => HAIRDRYER2,HAIRDRYER3,HAIRDRYER1
# haircut => HAIRCUT
# hairdresser => HAIRDRESSER
# half => HALF
# half_hour => HALFHOUR
# hall => HALL
# halloween => HALLOWEEN1,HALLOWEEN2
# hamburger => HAMBURGER
# hammer => HAMMER
# hamster => HAMSTER
# hand => HANDS
# hand_off => HANDSOFF
# hand_soap => HANDSOAP
# handcuff => HANDCUFFS
# handsome => HANDSOME4,HANDSOME2,HANDSOME1,HANDSOME3
# hang => HANG
# hang_clothe => HANGCLOTHES
# hanukkah => HANUKKAH
# happen => HAPPEN
# happy => HAPPY
# hard => HARD
# hard_of_hear => HARDOFHEARING
# harmonica => HARMONICA
# harp => HARP
# hat => HAT1,HAT2
# hat_brim => HATBRIM
# hatch => HATCH1,HATCH2
# hate => HATE
# have => HAVE
# have_enough => HADENOUGH
# hawaii => HAWAII
# he => HE
# head => HEAD
# head_back => HEADBACK
# head_cold => HEADCOLD
# head_grind => HEADGRIND
# headache => HEADACHE
# headphone => HEADPHONES
# health => HEALTH
# heap => HEAP
# hear => HEARING,HEAR2,HEAR1
# hear_aid => HEARINGAID
# heart => HEART
# heart_body => HEARTBODY
# heart_touch => HEARTTOUCH
# heaven => HEAVEN
# heavy => HEAVY
# helicopter => HELICOPTER3,HELICOPTER1,HELICOPTER2
# hell => HELL
# hello => HELLO
# helmet => HELMET2,HELMET1
# help => HELP
# hen => HEN
# here => HERE
# hide => HIDE
# high => HIGH
# high_heel => HIGHHEELS
# highlighter => HIGHLIGHTER
# highschool => HIGHSCHOOL
# hinge => HINGE
# hippo => HIPPO2,HIPPO1
# his => HIS
# history => HISTORY
# hit => HIT1,HIT2
# hitchhike => HITCHHIKE
# hockey => HOCKEY
# hoe => HOE
# hold => HOLD1,HOLD2
# hold_accountable => HOLDACCOUNTABLE
# hold_hand => HOLDHANDS
# hold_together => HOLDTOGETHER
# holiday => HOLIDAY
# holy => HOLY
# home => HOME
# homework => HOMEWORK
# honest => HONEST
# honey => HONEY2,HONEY1
# hongkong => HONGKONG
# honk => HONK
# honor => HONOR
# hood => HOOD
# hood_ie => HOODIE2,HOODIE1
# hop => HOP
# hope => HOPE
# horrible => HORRIBLE
# horse => HORSE
# hose => HOSE
# hospital => HOSPITAL2,HOSPITAL1
# hot => HOT
# hot_competition => HOTCOMPETITION
# hotdog => HOTDOG
# hotel => HOTEL
# hour => HOUR
# house => HOUSE
# how => HOW1,HOW2
# howl => HOWL
# hug => HUG
# humble => HUMBLE
# hummingbird => HUMMINGBIRD
# humor => HUMOR
# hundred => HUNDRED
# hungry => HUNGRY
# hunt => HUNT
# hurdle_trip => HURDLE-TRIP1,HURDLE-TRIP2
# hurricane => HURRICANE
# hurry => HURRY
# hurt => HURT
# husband => HUSBAND
# hypocrite => HYPOCRITE
# ice => ICE
# icecream => ICECREAM
# idea => IDEA
# identity => IDENTITY
# if => IF
# ignore => IGNORE
# iloveyou => ILOVEYOU
# imagine => IMAGINE1,IMAGINE2
# immature => IMMATURE
# immerse => IMMERSE
# impact => IMPACT
# important => IMPORTANT
# impossible => IMPOSSIBLE
# impress => IMPRESS
# improve => IMPROVE
# in => IN
# inch => INCH
# incredible => INCREDIBLE
# independent => INDEPENDENT
# indian => INDIAN
# inept => INEPT
# infection => INFECTION
# influence => INFLUENCE
# inhale => INHALE
# inject => INJECT
# innocent => INNOCENT
# inside => INSIDE
# inspire => INSPIRE,INSPIRING
# insta_gram => INSTAGRAM
# instead => INSTEAD
# instinct => INSTINCT
# institute => INSTITUTE
# insult => INSULT
# insurance => INSURANCE
# intelligent => INTELLIGENT
# intentional => INTENTIONAL
# interest => INTEREST
# interested => INTERESTED
# internet => INTERNET
# interpret => INTERPRET
# interpreter => INTERPRETER
# intervene => INTERVENE
# interview => INTERVIEW
# introduce => INTRODUCE
# intuitive => INTUITIVE
# invest => INVEST
# invisible => INVISIBLE
# invite => INVITE
# iphone => IPHONE
# iron => IRON3,IRON1,IRON2
# island => ISLAND
# isolate => ISOLATED
# israel => ISRAEL
# italy => ITALY
# itch => ITCH
# jacket => JACKET1,JACKET2,JACKET3,JACKET4
# japan => JAPAN
# jar => JAR
# jaw_drop => JAWDROP
# jealous => JEALOUS
# jelly => JELLY
# jellyfish => JELLYFISH
# jewelry => JEWELRY
# jewish => JEWISH
# jigsaw_puzzle => JIGSAWPUZZLE
# join => JOIN
# joke => JOKE
# journey => JOURNEY
# judge => JUDGE
# juggle => JUGGLE
# juggler => JUGGLER
# juice => JUICE1,JUICE2
# jump => JUMP
# jump_rope => JUMPROPE
# junior => JUNIOR
# kangaroo => KANGAROO3,KANGAROO1,KANGAROO2
# keep => KEEP
# key => KEY
# keyboard => KEYBOARD
# kick => KICK2,KICK1
# kid => KID
# kill => KILL
# kindergarten => KINDERGARTEN
# king => KING
# kiss => KISS2,KISS3,KISS1
# kiss_fist => KISSFIST
# kiss_on_cheek => KISSONCHEEK
# kitchen => KITCHEN
# kite => KITE2,KITE1
# kitten => KITTEN
# kneel => KNEEL
# knife => KNIFE2,KNIFE1
# knight => KNIGHT3,KNIGHT1,KNIGHT2,KNIGHT4
# knitting => KNITTING3,KNITTING1,KNITTING2
# knock => KNOCK
# knock_off => KNOCKOFF
# know => KNOW
# know_nothing => KNOWNOTHING
# label => LABEL
# lamp => LAMP2,LAMP1
# land => LAND
# language => LANGUAGE
# laptop => LAPTOP
# last => LAST
# last_week => LASTWEEK
# late => LATE
# later => LATER
# laugh => LAUGH
# law => LAW
# lawn_mower => LAWNMOWER
# lawyer => LAWYER
# lazy => LAZY
# lead => LEAD
# leaf => LEAF1,LEAF2
# league => LEAGUE
# leak => LEAK
# learn => LEARN
# learn_lesson => LEARNLESSON
# leather => LEATHER
# leave => LEAVE,LEFT
# leave_alone => LEAVEALONE
# lecture => LECTURE
# lemon => LEMON1,LEMON2
# lend => LEND
# lesbian => LESBIAN
# less => LESS
# lesson => LESSON
# let_I_see => LETMESEE
# let_go => LETGO
# let_know => LETKNOW
# letter => LETTER1,LETTER2
# lettuce => LETTUCE1,LETTUCE2
# library => LIBRARY
# license => LICENSE
# lick => LICK2,LICK1
# lick_envelope => LICKENVELOPE2,LICKENVELOPE1
# lie => LIE
# lie_down => LAYDOWN
# lift => LIFT1,LIFT2
# light => LIGHT
# light_candle => LIGHTCANDLE
# light_on => LIGHTSON
# lighter => LIGHTER
# lightning => LIGHTNING
# lightweight => LIGHTWEIGHT
# like => LIKE
# limit => LIMITED
# line => LINE
# linguistic => LINGUISTICS
# lion => LION
# lip => LIPS
# lipread => LIPREAD
# lipstick => LIPSTICK
# list => LIST
# listen => LISTEN
# live => LIVE2,LIVE1
# live_room => LIVINGROOM
# load => LOAD1,LOAD2
# lobster => LOBSTER3,LOBSTER2,LOBSTER1
# lock => LOCK1,LOCK2,LOCK3
# locker => LOCKER
# lollipop => LOLLIPOP
# lonely => LONELY
# long => LONG
# long_ago => LONGAGO
# long_line => LONGLINE
# long_word => LONGWORD
# longtime => LONGTIME
# look_appearance => LOOKAPPEARANCE
# look_at => LOOKAT
# look_back => LOOKBACK
# look_for => LOOKFOR
# look_forward => LOOKFORWARD
# look_like => LOOKLIKE
# lose => LOST,LOSE
# lose_game => LOSEGAME
# loud => LOUD
# lousy => LOUSY
# love => LOVE
# loyal => LOYAL
# luck => LUCK
# lucky => LUCKY
# lunch => LUNCH2,LUNCH1
# lung => LUNGS
# machine => MACHINE
# mad => MAD
# magazine => MAGAZINE
# magic => MAGIC
# magnet => MAGNET4,MAGNET3,MAGNET2,MAGNET1
# magnify => MAGNIFY1,MAGNIFY2
# maid => MAID
# mail => MAIL2,MAIL1
# mailman => MAILMAN
# mainstream => MAINSTREAM
# major => MAJOR
# make => MAKE
# make_believe => MAKEBELIEVE
# man => MAN
# manage => MANAGE
# many => MANY
# maple => MAPLE
# march => MARCH
# marionette => MARIONETTE
# marry => MARRY
# mascara => MASCARA
# massage => MASSAGE
# match => MATCH
# math => MATH
# maybe => MAYBE
# mcdonald => MCDONALDS
# mean => MEAN2,MEAN1
# measure => MEASURE2,MEASURE1
# meat => MEAT2,MEAT1
# mechanic => MECHANIC1,MECHANIC2
# medicine => MEDICINE
# meditate => MEDITATE2,MEDITATE3,MEDITATE1
# meet => MEET
# meeting => MEETING
# megaphone => MEGAPHONE
# melon => MELON
# melt => MELT
# member => MEMBER
# memorize => MEMORIZE
# memorize_memorize => MEMORIZEMEMORIZE
# mention => MENTION
# mess => MESS
# metal => METAL
# metaphor => METAPHOR
# mexican => MEXICAN1,MEXICAN2
# microphone => MICROPHONE
# microscope => MICROSCOPE2,MICROSCOPE3,MICROSCOPE1
# microwave => MICROWAVE
# middle => MIDDLE
# milk => MILK1,MILK2
# mime => MIME
# mind => MIND
# mind_turn => MINDTURNED
# mine => MINE
# minimum => MINIMUM2,MINIMUM1
# minute => MINUTE
# mirror => MIRROR
# mischievous => MISCHIEVOUS
# miss => MISS,MISSING
# misunderstand => MISUNDERSTAND
# mix => MIX2,MIX1,MIX3
# mock => MOCK
# model => MODEL2,MODEL1
# monday => MONDAY
# money => MONEY1,MONEY2
# monkey => MONKEY
# monster => MONSTER
# month => MONTH
# moon => MOON
# moose => MOOSE
# mop => MOP2,MOP1
# more => MORE
# morning => MORNING
# mosquito => MOSQUITO
# most => MOST
# mother => MOTHER
# motivation => MOTIVATION1,MOTIVATION2
# motorcycle => MOTORCYCLE
# mountain => MOUNTAIN2,MOUNTAIN1
# mouse => MOUSE
# mouth => MOUTH
# move => MOVE
# move_own => MOVEDOWN
# movie => MOVIE2,MOVIE1
# much => MUCH
# mummy => MUMMY
# murder => MURDER
# muscle => MUSCLE
# museum => MUSEUM
# mushroom => MUSHROOM
# music => MUSIC
# must => MUST
# mustache => MUSTACHE
# my => MY
# myself => MYSELF
# nail => NAIL
# nail_clipper => NAILCLIPPER
# naked => NAKED
# name => NAME
# napkin => NAPKIN
# navel => NAVEL
# navy => NAVY
# near => NEAR
# neck => NECK
# necklace => NECKLACE3,NECKLACE1,NECKLACE4,NECKLACE2
# need => NEED
# needle => NEEDLE
# negative => NEGATIVE
# nephew => NEPHEW
# nerve => NERVE
# net => NET
# network => NETWORK
# neutral => NEUTRAL
# never => NEVER
# new => NEW
# new_york => NEWYORK
# news_tome => NEWSTOME
# newspaper => NEWSPAPER
# next => NEXT
# next_down => NEXTDOWN
# next_to => NEXTTO
# next_year => NEXTYEAR
# nice => NICE
# niece => NIECE
# night => NIGHT1,NIGHT2
# nine => NINE
# no => NO
# no_big_deal => NOBIGDEAL
# noise => NOISE
# none => NONE
# nonsense => NONSENSE
# noon => NOON2,NOON1
# noose => NOOSE
# normal => NORMAL
# north => NORTH
# nose => NOSE
# nosebleed => NOSEBLEED
# not => NOT
# not_a_thing => NOTATHING
# not_care => NOTCARE
# not_interested => NOTINTERESTED
# not_mind => NOTMIND
# not_understand => NOTUNDERSTAND
# not_use_to => NOTUSEDTO
# not_yet => NOTYET
# nothing => NOTHING1,NOTHING2
# nothing_at_all => NOTHINGATALL
# now => NOW
# number => NUMBERS
# nurse => NURSE
# nut => NUT2,NUT1
# obsess => OBSESS
# obvious => OBVIOUS
# ocean => OCEAN
# octopus => OCTOPUS
# off => OFF
# off_the_point => OFFTHEPOINT
# offend => OFFEND
# offhand => OFFHAND
# office => OFFICE
# often => OFTEN
# oh_I_see => OHISEE
# oil => OIL3,OIL2,OIL1
# ok => OK
# old => OLD
# oldest => OLDEST
# on => ON
# once => ONCE
# one => ONE
# one_more => ONEMORE2,ONEMORE1
# one_year_ago => ONEYEARAGO
# onion => ONION
# only_one => ONLYONE
# ooh => OOH
# oops => OOPS
# open => OPEN
# open_book => OPENBOOK
# open_wallet => OPENWALLET
# operate_machine => OPERATEMACHINE
# opinion => OPINION1,OPINION2
# opportunity => OPPORTUNITY
# option => OPTION
# or => OR
# oral => ORAL
# orange => ORANGE
# orange_eye => ORANGEEYES
# orange_throat => ORANGETHROAT
# order => ORDER1,ORDER2
# organization => ORGANIZATION
# ostrich => OSTRICH
# other => OTHER
# our => OUR
# out => OUT
# outside => OUTSIDE
# over => OVER
# overlook => OVERLOOK
# overnight => OVERNIGHT
# overtake => OVERTAKE
# overwhelm => OVERWHELMED
# owe => OWE
# owl => OWL
# own => OWN
# pack => PACK
# page => PAGE
# pageant => PAGEANT
# pain => PAIN
# paint => PAINT
# paintbrush => PAINTBRUSH
# pair => PAIR
# pancake => PANCAKE
# pant => PANTS1,PANTS2
# paper => PAPER
# paper_cutter => PAPERCUTTER
# parachute => PARACHUTE1,PARACHUTE2,PARACHUTE3
# parade => PARADE
# paragraph => PARAGRAPH
# parallel => PARALLEL
# paranoid => PARANOID
# parent => PARENTS
# park => PARK
# party => PARTY1,PARTY2
# pass => PASS
# pass_out => PASSOUT
# passport => PASSPORT
# past => PAST
# patient => PATIENT2,PATIENT1,PATIENT3
# pay => PAY
# payoff_bill => PAYOFFBILLS
# pea => PEAS1,PEAS2
# peace => PEACE
# peach => PEACH2,PEACH1
# peacock => PEACOCK
# peanut_butter => PEANUTBUTTER
# pear => PEAR
# peck => PECK
# peekaboo => PEEKABOO
# peel => PEEL2,PEEL3,PEEL1
# peg => PEG2,PEG1,PEG3
# pen => PEN
# pencil => PENCIL
# penguin => PENGUIN
# penis => PENIS
# penny => PENNY
# people => PEOPLE
# pepper => PEPPER
# pepsi => PEPSI
# perceive => PERCEIVE
# percent => PERCENT
# perfect => PERFECT
# perfume => PERFUME1,PERFUME2
# period => PERIOD
# permission => PERMISSION
# persistent => PERSISTENT
# person => PERSON
# perspective => PERSPECTIVE
# persuade => PERSUADE
# pet => PET1,PET2
# pharmacist => PHARMACIST
# philadelphia => PHILADELPHIA
# philosophy => PHILOSOPHY
# phone => PHONE
# photography => PHOTOGRAPHY
# physics => PHYSICS
# piano => PIANO
# pick => PICK
# pickle => PICKLE
# picnic => PICNIC
# picture => PICTURE
# pie => PIE
# pig => PIG
# pile => PILE
# pill => PILL
# pillow => PILLOW1,PILLOW3,PILLOW2
# pin_on => PINON
# pinch => PINCH1,PINCH2
# pineapple => PINEAPPLE1,PINEAPPLE2,PINEAPPLE4,PINEAPPLE3,PINEAPPLE5
# pink => PINK
# pipe => PIPE4,PIPE3,PIPE1,PIPE2
# pirate => PIRATE
# piss_off => PISSEDOFF
# pitcher => PITCHER
# pity => PITY
# pizza => PIZZA2,PIZZA1
# pizza_cutter => PIZZACUTTER
# pj_s => PJS
# place => PLACE
# plain => PLAIN
# plan => PLAN
# planet => PLANET
# plant => PLANT
# plate => PLATE
# platform => PLATFORM
# play => PLAY
# player => PLAYERS
# playground => PLAYGROUND
# please => PLEASE
# plenty => PLENTY
# plier => PLIERS
# plow => PLOW2,PLOW1
# plug => PLUG2,PLUG1
# plummet => PLUMMET
# plunger => PLUNGER
# plus => PLUS
# point => POINT
# point_index => POINTINDEX
# pole => POLE
# policeman => POLICEMAN1,POLICEMAN2
# policy => POLICY
# polish => POLISH
# ponder => PONDER
# pool_game => POOLGAME
# poop => POOP
# poor => POOR
# pop => POP1,POP2,POP3,POP4
# popcorn => POPCORN
# pope => POPE
# popular => POPULAR
# porcupine => PORCUPINE
# positive => POSITIVE
# possible => POSSIBLE
# possum => POSSUM
# postpone => POSTPONE
# potato => POTATO
# pour => POUR2,POUR1
# powder => POWDER
# power => POWER
# practice => PRACTICE
# prayer => PRAYER
# preacher => PREACHER
# precious => PRECIOUS
# predict => PREDICT
# prefer => PREFER
# pregnant => PREGNANT
# president => PRESIDENT
# press => PRESS
# press_in_mind => PRESSINMIND
# pretend => PRETEND
# pretty => PRETTY
# price => PRICE
# pride => PRIDE
# priest => PRIEST
# prince => PRINCE
# principal => PRINCIPAL
# print => PRINT
# priority => PRIORITY
# prison => PRISON
# problem => PROBLEM2,PROBLEM1
# process => PROCESS
# produce_sign => PRODUCESIGN
# profoundly_deaf => PROFOUNDLYDEAF
# program => PROGRAM
# project => PROJECT
# promise => PROMISE
# promote => PROMOTE
# proof => PROOF
# propeller => PROPELLER
# propose => PROPOSE
# protection => PROTECTION
# protest => PROTEST
# provide => PROVIDE
# proxima_liz_ation => PROXIMALIZATION
# psychologist => PSYCHOLOGIST
# psychology => PSYCHOLOGY
# public => PUBLIC
# pull => PULL
# pull_convince => PULLCONVINCE
# pumpkin => PUMPKIN
# punch_face => PUNCHFACE
# punish => PUNISH
# purple => PURPLE
# push => PUSH
# put => PUT
# put_aside => PUTASIDE
# put_in_back_mind => PUTINBACKMIND
# puzzle => PUZZLED
# q_tip => QTIP
# qm => QM
# quality => QUALITY
# quarter => QUARTER
# queen => QUEEN
# quiet => QUIET
# quit => QUIT
# rabbit => RABBIT2,RABBIT1
# race => RACE
# racecar_track => RACECARTRACK
# radio => RADIO
# rain => RAIN
# rainbow => RAINBOW
# raisin => RAISIN
# rake => RAKE
# range => RANGE
# rat => RAT
# razor => RAZOR2,RAZOR1
# reach => REACH
# react => REACT
# read => READ
# ready => READY
# real_sick => REALSICK
# really => REALLY
# really_into => REALLYINTO
# reason => REASON
# recent => RECENT2,RECENT1
# recite => RECITE
# record => RECORD,RECORDING
# red => RED
# red_face => REDFACED
# reduce => REDUCE
# reflect => REFLECT
# refrigerator => REFRIGERATOR
# refuse => REFUSE
# register => REGISTER
# regular => REGULAR
# relationship => RELATIONSHIP
# relax => RELAX1,RELAX2
# release => RELEASE
# relief => RELIEF
# religion => RELIGION
# remember => REMEMBER2,REMEMBER1
# remind => REMIND
# remote_control => REMOTECONTROL
# remove => REMOVE
# replace => REPLACE
# request => REQUEST
# rescue => RESCUE
# research => RESEARCH2,RESEARCH1
# resent => RESENT
# resign => RESIGN
# resist => RESIST
# respect => RESPECT
# responsibility => RESPONSIBILITY
# rest => REST
# rest_all_day => RESTALLDAY
# restaurant => RESTAURANT
# restless => RESTLESS
# result => RESULT
# retire => RETIRE
# retrieve => RETRIEVE
# revenge => REVENGE
# rhino => RHINO2,RHINO3,RHINO1
# ribbon_award => RIBBONAWARD
# rich => RICH
# ride => RIDE1,RIDE2
# right => RIGHT1,RIGHT2,RIGHT3
# ring => RING
# rise => ROSE
# risk => RISK
# river => RIVER2,RIVER1
# road => ROAD
# roar => ROAR1,ROAR2
# roast => ROAST
# rob => ROB
# robot => ROBOT
# rock => ROCK
# rock_chair => ROCKINGCHAIR1,ROCKINGCHAIR2
# rocket => ROCKET2,ROCKET1
# role => ROLE
# roll => ROLL
# roller_b_lading => ROLLERBLADING
# rollerskate => ROLLERSKATING
# rollup_sleeve => ROLLUPSLEEVES
# roof => ROOF
# room => ROOM
# roommate => ROOMMATE
# rooster => ROOSTER
# rope => ROPE
# rough => ROUGH
# row => ROW
# rude => RUDE
# ruin => RUIN
# rule => RULE
# ruler => RULER
# run => RUN1,RUN2
# run_faucet => RUNFAUCET
# run_out_of => RUNOUTOF
# rush => RUSH
# russia => RUSSIA
# s_can => SCAN
# s_have => SHAVE2,SHAVE4,SHAVE3,SHAVE1,SHAVE5
# s_it => SIT
# s_of_a => SOFA
# sad => SAD
# safe => SAFE
# sail => SAIL2,SAIL1
# sailboat => SAILBOAT
# salad => SALAD
# salt => SALT
# saltshaker => SALTSHAKER
# same => SAME1,SAME2
# same_same => SAMESAME
# sametime => SAMETIME
# sandal => SANDALS
# sandwich => SANDWICH3,SANDWICH4,SANDWICH2,SANDWICH1
# santa => SANTA
# sarcastic => SARCASTIC
# saturday => SATURDAY
# sauce => SAUCE
# sausage => SAUSAGE
# save => SAVE
# save_money => SAVEMONEY
# saxophone => SAXOPHONE
# scar => SCARED
# scar_memory => SCARMEMORY
# scarcely => SCARCELY
# scarf => SCARF4,SCARF2,SCARF3,SCARF1
# school => SCHOOL
# science => SCIENCE
# scientist => SCIENTIST
# scissor => SCISSORS
# scold => SCOLD
# scoop => SCOOP
# score => SCORE
# scout => SCOUT
# scratch => SCRATCH
# scream => SCREAM
# screwdriver => SCREWDRIVER2,SCREWDRIVER1,SCREWDRIVER3
# script => SCRIPT
# scroll_down => SCROLLDOWN
# scrub => SCRUB
# sculpt => SCULPT
# sculpture => SCULPTURE
# seal => SEAL
# secret => SECRET
# secretary => SECRETARY
# see => SAW2,SEE,SAW1
# see_see => SEESEE
# seem => SEEM
# select => SELECT
# self => SELF
# sell => SELL
# senate => SENATE
# send => SEND
# senior_citizen => SENIORCITIZEN
# sensitive => SENSITIVE
# sentence => SENTENCE2,SENTENCE1
# sequence => SEQUENCE
# serious => SERIOUS
# serve => SERVE2,SERVE1
# setup => SETUP
# seven => SEVEN
# several => SEVERAL
# sew => SEW
# shake => SHAKE2,SHAKE1
# shakespeare => SHAKESPEARE
# shame => SHAME
# shame_on_you => SHAMEONYOU
# shampoo => SHAMPOO
# shape => SHAPE
# share => SHARE
# shark => SHARK2,SHARK1
# sharp => SHARP2,SHARP1
# sharpen => SHARPEN2,SHARPEN1,SHARPEN3
# sheep => SHEEP
# shelf => SHELF
# shield => SHIELD
# shiny => SHINY
# shirt => SHIRT1,SHIRT2
# shock => SHOCKED
# shoe => SHOES
# shoot => SHOOTING,SHOOT2,SHOT,SHOOT1
# shop => SHOP2,SHOP1
# short => SHORTS
# short_distance => SHORTDISTANCE
# short_person => SHORTPERSON
# short_word => SHORTWORD
# should => SHOULD
# shoulder => SHOULDER2,SHOULDER1,SHOULDER3
# shout => SHOUT2,SHOUT1
# shovel => SHOVEL1,SHOVEL2
# show => SHOW
# shower => SHOWER
# shrimp => SHRIMP
# shutout => SHUTOUT
# shy => SHY
# sick => SICK
# side => SIDE
# sideburn => SIDEBURNS
# sign => SIGN
# sign_fluently => SIGNINGFLUENTLY
# sign_language => SIGNLANGUAGE
# sign_paper => SIGNPAPER
# signature => SIGNATURE
# silly => SILLY
# silver => SILVER
# since => SINCE
# sing => SING
# single => SINGLE
# single_out => SINGLEOUT
# sink => SINK
# siren => SIREN
# sister => SISTER
# situation => SITUATION
# six => SIX
# skate => SKATE
# skateboard => SKATEBOARDING1,SKATEBOARDING3,SKATEBOARDING2
# ski => SKI
# ski_can => SKI-CA
# skill => SKILL
# skin => SKIN
# skirt => SKIRT
# skunk => SKUNK
# slave => SLAVE
# sle => SLED1,SLED2
# sleep => SLEEP
# slice => SLICE2,SLICE4,SLICE3,SLICE1
# slide => SLIDE2,SLIDE1
# slingshot => SLINGSHOT
# slip => SLIP2,SLIP1
# slipper => SLIPPER
# slow => SLOW
# small => SMALL
# smart => SMART
# smell => SMELL
# smell_money => SMELLMONEY
# smile => SMILE1,SMILE2
# smoke => SMOKING,SMOKE
# smooth => SMOOTH
# snail => SNAIL
# snake => SNAKE
# snap => SNAP
# snap_stick => SNAPSTICK
# sneak_adventure => SNEAKADVENTURE
# sneeze => SNEEZE2,SNEEZE1
# snob => SNOB
# snorkel => SNORKEL
# snow => SNOW2,SNOW1
# snowboard => SNOWBOARD
# snowman => SNOWMAN
# snowsuit => SNOWSUIT
# so => SO
# soap => SOAP2,SOAP1
# soccer => SOCCER2,SOCCER1
# social => SOCIAL
# socialize => SOCIALIZE
# society => SOCIETY
# sock => SOCKS
# soda => SODA
# soft => SOFT
# softball => SOFTBALL
# some => SOME
# somersault => SOMERSAULT1,SOMERSAULT3,SOMERSAULT2
# something => SOMETHING
# sometimes => SOMETIMES
# son => SON
# soon => SOON1,SOON2
# sophisticated => SOPHISTICATED
# sophomore => SOPHOMORE
# sorry => SORRY
# sound => SOUND
# soup => SOUP
# sour => SOUR
# south => SOUTH
# sow => SOW
# space => SPACE
# spaceship => SPACESHIP
# spaghetti => SPAGHETTI
# spain => SPAIN
# speaker => SPEAKERS
# special => SPECIAL1,SPECIAL2
# specialist => SPECIALIST
# specific => SPECIFIC
# spend => SPEND
# spend_lot_of_money => SPENDLOTSOFMONEY
# spicy => SPICY
# spider => SPIDER
# spill => SPILL2,SPILL1
# spit_out => SPITOUT
# splash_can => SPLASH-CA
# spontaneous => SPONTANEOUS
# spoon => SPOON
# sport => SPORTS
# spot_something => SPOTSOMETHING
# spread => SPREAD2,SPREAD3,SPREAD1
# spring => SPRING
# square => SQUARE
# square_idiot => SQUAREIDIOT
# squeeze => SQUEEZE
# squirrel => SQUIRREL
# ssh_h => SSHH
# stack => STACK2,STACK3,STACK4,STACK1
# stadium => STADIUM
# staff => STAFF
# stair => STAIRS
# stamp => STAMP2,STAMP1,STAMP3
# stand => STAND1,STAND2
# stand_up => STAND-UP
# stapler => STAPLER
# star => STAR,STARS
# starbuck => STARBUCKS
# stare => STARE
# start => START
# state => STATE
# stay => STAY
# stay_awake_24_hrs => STAYAWAKE24HRS
# steak => STEAK
# steal => STEAL
# steam => STEAM
# step => STEP
# stethoscope => STETHOSCOPE2,STETHOSCOPE1,STETHOSCOPE3,STETHOSCOPE4
# stick => STUCK
# sticky => STICKY
# still => STILL
# stimulate => STIMULATE
# sting => STING
# stink => STINK
# stir => STIR
# stocking => STOCKINGS
# stomach => STOMACH
# stop => STOP
# stopwatch => STOPWATCH
# story => STORY1,STORY2,STORY3
# straight => STRAIGHT
# strain => STRAIN2,STRAIN1
# strange => STRANGE
# strangle => STRANGLE
# straw => STRAW
# strawberry => STRAWBERRY4,STRAWBERRY3,STRAWBERRY1,STRAWBERRY2
# street => STREET
# stress => STRESS
# stretch => STRETCH2,STRETCH1
# stretch_can => STRETCH-CA
# strict => STRICT
# string => STRING
# stripe => STRIPE
# strong => STRONG
# structure => STRUCTURE
# struggle => STRUGGLE
# stubborn => STUBBORN
# student => STUDENT
# study => STUDY
# stumble => STUMBLE
# stupid => STUPID1,STUPID2
# subtract => SUBTRACT
# suck => SUCK
# suck_thumb => SUCKTHUMB
# suit => SUIT
# summarize => SUMMARIZE
# summer => SUMMER
# summon => SUMMON
# sun => SUN
# sunbathe => SUNBATHE2,SUNBATHE1
# sunday => SUNDAY
# sunrise => SUNRISE
# sunset => SUNSET
# superior => SUPERIOR
# supervise => SUPERVISE
# supervisor => SUPERVISOR
# support => SUPPORT2,SUPPORT1
# sure => SURE
# surf => SURF
# surgeon => SURGEON
# surgery => SURGERY
# surprise => SURPRISE
# sushi => SUSHI
# suspect => SUSPECT
# suspend => SUSPEND
# suspender => SUSPENDERS1,SUSPENDERS2
# swallow => SWALLOW
# swear_in => SWEARIN
# sweat => SWEAT
# sweater => SWEATER3,SWEATER2,SWEATER1
# sweatpant => SWEATPANTS
# sweatshirt => SWEATSHIRT
# sweep => SWEEP
# sweet => SWEET
# sweetheart => SWEETHEART
# swim => SWIM1,SWIM2
# swing => SWING1,SWING2
# switzerland => SWITZERLAND
# sword => SWORD
# sympathy => SYMPATHY
# system => SYSTEM
# table => TABLE
# tablet => TABLET
# tail => TAIL1,TAIL2
# take => TAKE
# take_care => TAKECARE
# take_note => TAKENOTES
# take_pill => TAKEPILL
# takeoff => TAKEOFF1,TAKEOFF2
# talk => TALK2,TALK1
# talk_dirty => TALKDIRTY
# tall => TALL1,TALL2
# tan => TAN
# tank_top => TANKTOP
# tape => TAPE
# taste => TASTE
# tea => TEA
# teach => TEACH2,TEACH1
# teacher => TEACHER
# team => TEAM
# tear => TEAR
# tear_rip => TEARRIP2,TEARRIP1
# tease => TEASE
# technology => TECHNOLOGY
# teenager => TEENAGER
# tell => TELL
# temper_blowup => TEMPERBLOWUP
# temporary => TEMPORARY
# temptation => TEMPTATION
# tend_your => TENDYOUR
# tendency => TENDENCY
# tennis => TENNIS
# tent => TENT
# test => TEST
# text => TEXT
# than => THAN
# thanksgive => THANKSGIVING
# thankyou => THANKYOU
# that => THAT
# theatre => THEATRE
# then => THEN
# theory => THEORY
# therapy => THERAPY
# there => THERE
# thermometer => THERMOMETER
# these => THESE
# they => THEY2,THEY1
# thief => THIEF2,THIEF1
# thin => THIN
# thing => THINGS
# think => THINK
# think_chin => THINKCHIN
# think_connect => THINKCONNECT
# think_disappear => THOUGHTDISAPPEAR
# think_expand => THINKEXPAND
# think_obsess => THINKOBSESS
# think_over => THINKOVER
# think_penetrate => THINKPENETRATE
# think_ponder => THINKPONDER
# third => THIRD2,THIRD1
# thirsty => THIRSTY
# this_it => THIS-IT
# three => THREE
# thrill => THRILLED
# throw => THROW2,THROW1
# throwaway => THROWAWAY
# thunder => THUNDER
# thursday => THURSDAY
# ticket => TICKET
# tickle => TICKLE
# tie => TIE1,TIE2
# tie_up => TIEUP2,TIEUP1
# tiger => TIGER
# time => TIME
# time_out => TIMEOUT
# time_progress => TIMEPROGRESS
# time_to_time => TIMETOTIME
# tiny => TINY
# tired => TIRED
# tired_of => TIREDOF
# tissue => TISSUE
# to => TO
# to_a_goal => TOAGOAL
# toast => TOAST
# tobacco => TOBACCO
# today => TODAY
# together => TOGETHER
# toilet => TOILET
# tomato => TOMATO
# tomorrow => TOMORROW
# tongue => TONGUE
# too_much => TOOMUCH
# tooth => TEETH
# toothbrush => TOOTHBRUSH
# toothbrush_can => TOOTHBRUSH-CA
# top => TOP
# topic => TOPIC
# tornado => TORNADO
# toss => TOSS
# toss_out => TOSSOUT
# total => TOTAL
# touch => TOUCH
# tough => TOUGH
# tournament => TOURNAMENT
# tow => TOW3,TOW2,TOW1
# towel => TOWEL
# toy => TOY3,TOY2,TOY1
# tractor => TRACTOR
# tradition => TRADITION
# traffic => TRAFFIC
# train => TRAIN
# transfer => TRANSFER
# transgender => TRANSGENDER
# translate => TRANSLATE
# trash => TRASH
# travel => TRAVEL
# tree => TREE
# triangle => TRIANGLE
# trim => TRIM2,TRIM1
# trip => TRIP1,TRIP2
# triple => TRIPLE
# trophy => TROPHY
# trouble => TROUBLE
# truck => TRUCK2,TRUCK1
# true => TRUE
# true_business => TRUEBUSINESS
# truth => TRUTH
# try => TRY
# tty => TTY
# tube => TUBE
# tube_top => TUBETOP
# tuesday => TUESDAY
# turban => TURBAN
# turkey => TURKEY1,TURKEY2
# turn => TURN
# turnaround => TURNAROUND
# turnkey => TURNKEY
# turtle => TURTLE
# tv => TV
# twin => TWINS2,TWINS1
# twirl => TWIRL
# two => TWO
# two_more => TWOMORE
# two_of_we => TWOOFUS
# two_week => TWOWEEKS
# type => TYPE2,TYPE1
# udder => UDDER
# ugly => UGLY
# umbrella => UMBRELLA
# unaware => UNAWARE
# uncertain => UNCERTAIN
# uncle => UNCLE
# under => UNDER
# undergraduate => UNDERGRADUATE
# understand => UNDERSTAND
# underwear => UNDERWEAR2,UNDERWEAR1
# unicorn => UNICORN
# unique => UNIQUE
# universe => UNIVERSE
# university => UNIVERSITY
# until => UNTIL
# up => UP
# upload => UPLOAD
# upset => UPSET1,UPSET2
# use => USE
# v_log => VLOG
# vacation => VACATION
# vacuum => VACUUM
# vagina => VAGINA
# vain => VAIN
# validate => VALIDATE
# valley => VALLEY
# value => VALUE
# vampire => VAMPIRE
# vanilla => VANILLA
# vanish => VANISH
# vase => VASE
# vegetable => VEGETABLE
# verb => VERB
# very => VERY
# very_interested => VERYINTERESTED
# vest => VEST
# vibrate => VIBRATE
# video_phone => VIDEOPHONE
# videocamera => VIDEOCAMERA2,VIDEOCAMERA1
# videogame => VIDEOGAME
# view => VIEW
# village => VILLAGE
# violin => VIOLIN
# vision => VISION
# visit => VISIT
# visitor => VISITOR
# visualize => VISUALIZE
# vitamin => VITAMINS
# vocabulary => VOCABULARY
# voice => VOICE
# volleyball => VOLLEYBALL
# volunteer => VOLUNTEER
# vomit => VOMIT
# vote => VOTE
# wade => WADE2,WADE1
# wait => WAIT
# waiter => WAITER
# walk => WALK1,WALK2
# walk_tightrope_cl => WALK-TIGHTROPE-CL
# wall => WALL
# wallet => WALLET
# walrus => WALRUS
# wand => WAND
# wander => WANDER
# want => WANT1,WANT2
# war => WAR
# warm => WARM
# warn => WARN
# wash => WASH1,WASH2
# wash_dish => WASHDISHES
# wash_face => WASHFACE2,WASHFACE1
# wash_hand => WASHHANDS
# wash_machine => WASHMACHINE
# waste => WASTE
# watch => WATCH
# water => WATER
# water_drop => WATERDROP
# water_ski => WATERSKI
# wave => WAVE
# way => WAY
# we => WE,US
# we_will_see => WEWILLSEE
# weak => WEAK
# wear => WEAR
# weather => WEATHER
# weave => WEAVE
# wedding => WEDDING
# wednesday => WEDNESDAY
# week => WEEK
# weekend => WEEKEND
# weigh => WEIGH
# weight => WEIGHT
# weird => WEIRD
# welcome => WELCOME2,WELCOME1
# well => WELL,BETTER,BEST
# west => WEST
# wet => WET
# whale => WHALE
# what => WHAT1,WHAT2,W.H.A.T
# what_for => WHATFOR1,WHATFOR2,WHATFOR3
# whatever => WHATEVER
# wheel => WHEEL
# wheelbarrow => WHEELBARROW
# wheelchair => WHEELCHAIR
# when => WHEN
# where => WHERE
# which => WHICH
# while => WHILE
# whip => WHIP
# whisper => WHISPER
# whistle => WHISTLE1,WHISTLE2
# white => WHITE
# white_person => WHITEPERSON
# who => WHO
# whole => WHOLE
# why => WHY
# why_not => WHYNOT
# wide => WIDE
# wife => WIFE
# will => WILL
# will_go => WILLGO
# win => WIN
# wind => WIND
# windmill => WINDMILL1,WINDMILL3,WINDMILL2
# window => WINDOW
# window_open => WINDOWOPEN
# windy => WINDY
# wine => WINE
# wink => WINK
# winter => WINTER
# wise => WISE
# wish => WISH
# witch => WITCH2,WITCH1
# with => WITH
# without => WITHOUT
# wolf => WOLF
# woman => WOMAN1,WOMAN2
# wonder => WONDER
# wood => WOOD
# word => WORD
# work => WORK
# workout => WORKOUT
# workshop => WORKSHOP
# world => WORLD
# worm => WORM
# worry => WORRY
# wow => WOW
# wrap => WRAP
# wrap_up => WRAPUP2,WRAPUP1
# wrestle => WRESTLE
# wring => WRING
# wristwatch => WRISTWATCH3,WRISTWATCH1,WRISTWATCH2
# write => WRITE
# write_on_wall => WRITEONWALL
# wrong => WRONG
# yawn => YAWN2,YAWN1,YAWN4,YAWN3
# yay => YAY
# yeah => YEAH
# year => YEAR
# yellow => YELLOW
# yes => YES
# yesterday => YESTERDAY
# you => YOU
# young => YOUNG
# your => YOUR
# yourself => YOURSELF
# yoyo => YOYO
# yucky => YUCKY
# zebra => ZEBRA
# zero => ZERO
# zipper => ZIPPER
# zoo => ZOO
# zoom_in => ZOOMIN
# zoom_off => ZOOMOFF

# %%
import csv

# %%
nsgl_word_list = []


with open('./NGSL_1.2_lemmatized_for_research.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        nsgl_word_list.append(row[0])
        # print(row[0])

# %%
og_clean_nsglwordlist = {word : word.rstrip(string.digits).replace(".","").lower() for word in nsgl_word_list}

# %%
nsgllemmatisedwords = {og_word : lemmatize(clean_word) for og_word,clean_word in og_clean_nsglwordlist.items()}

# lemmatisedwords = {word:lemmatize(word) for word in wordlist}
with open("./nsgl_words_lemmatised.txt","w") as f:
    for k,v in nsgllemmatisedwords.items():
        f.write(f"{v}\n")
    
nsgl_words_lemmatised = nsgllemmatisedwords.values()

print(len(nsgl_words_lemmatised))
# Out:
# 2809

# %%
set_of_dataset_words = set(dataset_words_lemmatised)

print(len(set_of_dataset_words))
print(len(dataset_words_lemmatised))
# Out:
# 2273
# 2731

# %%
set_of_nsgl_words = set(nsgl_words_lemmatised)

print(len(set_of_nsgl_words))
print(len(nsgl_words_lemmatised))
# Out:
# 2801
# 2809

# %%
common = set_of_dataset_words & set_of_nsgl_words

print(len(common))

print(sorted(common))
# Out:
# 1123
# ['I', 'about', 'above', 'accept', 'access', 'accident', 'accomplish', 'acquire', 'act', 'action', 'actor', 'add', 'address', 'admire', 'admit', 'adopt', 'adult', 'advantage', 'advertise', 'after', 'afternoon', 'again', 'against', 'age', 'agency', 'agreement', 'alarm', 'alcohol', 'all', 'alone', 'alright', 'always', 'analyze', 'and', 'angry', 'animal', 'announce', 'answer', 'any', 'anyone', 'apart', 'appear', 'appointment', 'area', 'argue', 'arm', 'army', 'arrest', 'arrive', 'art', 'article', 'ask', 'assign', 'assist', 'assistant', 'at', 'athlete', 'attention', 'attitude', 'audience', 'aunt', 'average', 'avoid', 'award', 'away', 'baby', 'back', 'bad', 'bag', 'balance', 'ball', 'bank', 'bar', 'barely', 'basic', 'bath', 'beach', 'bear', 'beat', 'because', 'become', 'bed', 'bedroom', 'beer', 'before', 'behavior', 'behind', 'believe', 'bell', 'belt', 'bend', 'benefit', 'bet', 'between', 'big', 'bind', 'bird', 'birth', 'bite', 'black', 'blame', 'bless', 'blind', 'blood', 'blow', 'blue', 'board', 'boat', 'body', 'bomb', 'bone', 'book', 'boot', 'bore', 'borrow', 'boss', 'both', 'bother', 'bottle', 'bottom', 'bowl', 'box', 'boy', 'bread', 'break', 'breakfast', 'breathe', 'bridge', 'bright', 'bring', 'brother', 'brown', 'brush', 'budget', 'build', 'burn', 'bury', 'bus', 'business', 'busy', 'but', 'button', 'buy', 'cake', 'call', 'calm', 'camera', 'can', 'cancel', 'cancer', 'capture', 'car', 'card', 'careful', 'carry', 'castle', 'cat', 'catch', 'category', 'cause', 'celebrate', 'center', 'chain', 'chair', 'challenge', 'champion', 'chance', 'change', 'channel', 'character', 'charge', 'chase', 'chat', 'cheap', 'check', 'cheek', 'cheese', 'child', 'chocolate', 'church', 'cigarette', 'circle', 'city', 'class', 'clause', 'clean', 'clear', 'click', 'clock', 'close', 'clothe', 'cloud', 'coach', 'coffee', 'coin', 'cold', 'college', 'color', 'come', 'comfortable', 'comment', 'committee', 'communication', 'community', 'complain', 'complex', 'computer', 'concept', 'concern', 'conduct', 'confident', 'conflict', 'confuse', 'connection', 'consume', 'contact', 'continue', 'convince', 'cook', 'cool', 'copy', 'corner', 'cost', 'cough', 'count', 'country', 'cousin', 'cow', 'crack', 'crash', 'crazy', 'cream', 'create', 'cross', 'cry', 'culture', 'cup', 'curious', 'curtain', 'cut', 'damn', 'dance', 'danger', 'dark', 'date', 'daughter', 'day', 'death', 'decide', 'decline', 'dedicate', 'deep', 'defeat', 'degree', 'demand', 'deny', 'department', 'depress', 'depth', 'desert', 'design', 'destroy', 'develop', 'die', 'different', 'dig', 'dinner', 'director', 'dirty', 'disappear', 'disappoint', 'discuss', 'divide', 'divorce', 'doctor', 'document', 'dog', 'door', 'double', 'doubt', 'down', 'drag', 'draw', 'dream', 'dress', 'drink', 'drive', 'drop', 'drug', 'dry', 'due', 'duty', 'each', 'ear', 'early', 'earn', 'earth', 'east', 'easy', 'eat', 'edge', 'edit', 'effect', 'egg', 'either', 'email', 'embarrass', 'emotion', 'emphasis', 'empty', 'end', 'enemy', 'energy', 'engineer', 'enjoy', 'enough', 'enter', 'envelope', 'environment', 'equal', 'escape', 'evaluate', 'even', 'event', 'everyday', 'everything', 'evidence', 'example', 'excite', 'excuse', 'exercise', 'expect', 'expensive', 'experience', 'experiment', 'expert', 'explanation', 'express', 'eye', 'face', 'fade', 'fail', 'fair', 'fall', 'family', 'famous', 'fan', 'far', 'farm', 'fashion', 'fast', 'fat', 'father', 'fault', 'favorite', 'feed', 'feel', 'fence', 'few', 'fight', 'figure', 'file', 'film', 'filter', 'finally', 'finance', 'find', 'fine', 'finger', 'finish', 'fire', 'first', 'fish', 'fit', 'fix', 'flag', 'float', 'floor', 'flower', 'fly', 'focus', 'fold', 'follow', 'fool', 'football', 'for', 'forest', 'forever', 'form', 'former', 'frame', 'free', 'freedom', 'freeze', 'friend', 'friendly', 'from', 'front', 'fruit', 'full', 'fun', 'function', 'funny', 'furniture', 'future', 'game', 'gas', 'gate', 'gay', 'generation', 'gesture', 'get', 'gift', 'girl', 'give', 'glass', 'go', 'goal', 'god', 'gold', 'golf', 'good',  ...

# %%
dataset_minus_nsgl = set_of_dataset_words - set_of_nsgl_words

print(len(dataset_minus_nsgl))

print(sorted(dataset_minus_nsgl))
# Out:
# 1150
# ['1_dollar', '5_dollar', '8_hour', '9_o_clock', 'I_a_culpa', 'a_line_bob', 'a_little_bit', 'abbreviate', 'absolutely_nothing', 'accent', 'accordion', 'accountant', 'addict', 'africa', 'airplane', 'alaska', 'align', 'all_day', 'all_go', 'all_of_sudden', 'all_over', 'all_over_body', 'all_way', 'alltogether', 'alphabet', 'amazing', 'america', 'angel', 'antler', 'apple', 'april', 'archeology', 'arizona', 'articulate_sign', 'asia', 'assembly', 'astronaut', 'atlanta', 'auditorium', 'australia', 'autism', 'automatic', 'awake', 'awkward', 'axe', 'babysitter', 'bachelor', 'back_out', 'backpack', 'backup', 'backyard', 'bacon', 'badge', 'bake', 'bald', 'balloon', 'banana', 'band_aid', 'bandage', 'bark', 'barrette', 'baseball', 'baseball_cap', 'basement', 'basket', 'basketball', 'bat', 'bathroom', 'bathtub', 'battery', 'beak', 'bean', 'beanie', 'beard', 'beaver', 'bee', 'beg', 'berry', 'bib', 'bicycle', 'binocular', 'biology', 'birthday', 'bison', 'bitch', 'bite_on_arm', 'bite_on_neck', 'blackbird', 'blank', 'blanket', 'bleed', 'blink', 'blond', 'bloom', 'blouse', 'blow_candle', 'blow_mind', 'blur', 'blush', 'boil', 'boil_mad', 'bolt', 'boston', 'bounce', 'bow', 'bow_tie', 'boyfriend', 'bra', 'bracelet', 'brag', 'braid', 'braille', 'brainstorm', 'brainwash', 'brave', 'break_time', 'breakdown', 'brick', 'bridesmaid', 'bubble', 'buckle', 'buffalo', 'bug', 'bull', 'bulldozer', 'bullshit', 'bumpy', 'bun', 'burp', 'bust', 'butter', 'butterfly', 'bye', 'cabinet', 'cafeteria', 'calculator', 'calendar', 'california', 'call_attention', 'call_tty', 'camcorder', 'camel', 'cameraman', 'camping', 'canada', 'cancellation', 'candle', 'candy', 'cannon', 'canoe', 'cape', 'caption', 'car_accident', 'car_battery', 'carousel', 'carrot', 'carve', 'casual', 'catapult', 'catch_baseball', 'cate_pillar', 'catholic', 'ceiling', 'celery', 'cellphone', 'cemetery', 'cereal', 'certificate', 'champ', 'chaos', 'charge_card', 'cheat', 'cheer', 'cheerleader', 'cheese_grater', 'cherish', 'cherry', 'chew', 'chew_2_mouth', 'chicago', 'chimney', 'chin', 'china', 'choke', 'chop', 'chopsticks', 'christmas', 'churn', 'cigar', 'circus_wheel', 'clap', 'clash', 'claw', 'cleft_chin', 'client', 'climb_ladder', 'clip', 'close_door', 'close_eye', 'closet', 'clown', 'clueless', 'coca_cola', 'cocaine', 'coconut', 'comb', 'come_here', 'come_out', 'commute', 'compass', 'computer_mouse', 'confidential', 'congratulation', 'contact_len', 'cookie', 'cooperate', 'corkscrew', 'corn', 'couch', 'counselor', 'cover_up', 'cowboy', 'cracker', 'cranky', 'crash_plane', 'crawl', 'credit_card', 'crew_cut', 'crocodile', 'cross_heart', 'crown', 'crumple', 'curl', 'curly_hair', 'curtsey', 'cut_remove_vid', 'cute', 'dancer', 'dart', 'deaf', 'deaf_school', 'deal_card', 'decorate', 'deer', 'deflate', 'delegate', 'deliberate', 'delicious', 'delinquent', 'demote', 'dent', 'dentist', 'deodorant', 'depend_on', 'dessert', 'devil', 'devour', 'diamond', 'diaper', 'dice', 'dictionary', 'different_situation', 'dig_up', 'dilemma', 'dining_room', 'dinosaur', 'dip', 'disagreement', 'disconnect', 'dislike', 'disney', 'dispatch', 'disrupt', 'dissect', 'dissolve', 'distract', 'dive', 'dizzy', 'do_care', 'do_feel_like', 'do_know', 'do_like', 'do_matter', 'do_mind', 'do_need', 'do_want', 'dodo', 'doll', 'dolphin', 'dominant', 'donkey', 'donut', 'dormitory', 'downhill', 'download', 'downsize', 'dragon', 'drawer', 'dreadlock', 'dresser', 'dressup', 'dribble', 'drill', 'drip', 'drown', 'drum', 'drunk', 'dryer', 'duck', 'dumb', 'dye', 'each_other', 'eagle', 'ear_up', 'earmuff', 'earring', 'earthquake', 'easel', 'easter', 'easy_to_do', 'eclipse', 'eggbeater', 'ego', 'egypt', 'eight', 'electrician', 'electrocute', 'elegance', 'elementary_school', 'elephant', 'elevator', 'eleven', 'emperor', 'engagement', 'engine_start', 'english', 'erase', 'eraser', 'erupt', 'escalate', 'escalator', 'europe', 'every_night', 'every_year', 'explode', 'eye_awake', 'eye_turn', 'eyeglass', 'faculty', 'faint', 'fake', 'fall_asleep', 'fantasy', 'fascinated ...

# %%
nsgl_minus_dataset =   set_of_nsgl_words - set_of_dataset_words

print(len(nsgl_minus_dataset))

print(sorted(nsgl_minus_dataset))
# Out:
# 1678
# ['a', 'abandon', 'ability', 'able', 'abortion', 'abroad', 'absence', 'absolute', 'absolutely', 'abstract', 'abuse', 'academic', 'acceptable', 'accommodation', 'accompany', 'accord', 'account', 'accurate', 'accuse', 'achieve', 'achievement', 'acknowledge', 'acquisition', 'across', 'active', 'activity', 'actual', 'actually', 'ad', 'adapt', 'addition', 'additional', 'adequate', 'adjust', 'adjustment', 'administration', 'advance', 'adventure', 'advertisement', 'advice', 'advise', 'adviser', 'advocate', 'affair', 'affect', 'afford', 'afraid', 'agenda', 'agent', 'aggressive', 'ago', 'agree', 'agricultural', 'ahead', 'aid', 'aim', 'air', 'aircraft', 'airline', 'album', 'alive', 'allege', 'allow', 'ally', 'almost', 'along', 'alongside', 'already', 'also', 'alter', 'alternative', 'although', 'altogether', 'amaze', 'amendment', 'among', 'amount', 'analysis', 'analyst', 'ancient', 'anger', 'angle', 'announcement', 'annual', 'another', 'anticipate', 'anxiety', 'anxious', 'anybody', 'anymore', 'anything', 'anyway', 'anywhere', 'apartment', 'apologize', 'apparent', 'apparently', 'appeal', 'appearance', 'application', 'apply', 'appoint', 'appreciate', 'approach', 'appropriate', 'approval', 'approve', 'approximately', 'architecture', 'argument', 'arise', 'around', 'arrange', 'arrangement', 'arrival', 'artist', 'as', 'ashame', 'aside', 'assess', 'assessment', 'asset', 'assistance', 'associate', 'association', 'assume', 'assumption', 'assure', 'atmosphere', 'attach', 'attachment', 'attack', 'attempt', 'attend', 'attendance', 'attract', 'attraction', 'attractive', 'attribute', 'author', 'automatically', 'autumn', 'available', 'aware', 'awareness', 'awful', 'background', 'badly', 'ban', 'band', 'barrier', 'base', 'basically', 'basis', 'battle', 'be', 'beautiful', 'beauty', 'begin', 'behave', 'belief', 'belong', 'below', 'beneath', 'beside', 'besides', 'beyond', 'bias', 'bid', 'bike', 'bill', 'bin', 'biological', 'bit', 'block', 'blog', 'bloody', 'bond', 'boom', 'boost', 'border', 'boundary', 'brain', 'branch', 'brand', 'breast', 'breath', 'breed', 'brief', 'briefly', 'brilliant', 'broad', 'broadcast', 'bunch', 'burden', 'burst', 'buyer', 'by', 'cable', 'calculate', 'camp', 'campaign', 'candidate', 'cap', 'capability', 'capable', 'capacity', 'capital', 'carbon', 'care', 'career', 'carefully', 'carpet', 'case', 'cash', 'cast', 'catalog', 'celebration', 'cell', 'cent', 'central', 'century', 'ceremony', 'certain', 'certainly', 'chairman', 'chamber', 'championship', 'chapter', 'characteristic', 'characterize', 'charity', 'charm', 'chart', 'chemical', 'chest', 'chicken', 'chief', 'childhood', 'chip', 'choice', 'choose', 'circumstance', 'cite', 'citizen', 'civil', 'civilian', 'claim', 'classic', 'classical', 'clearly', 'climate', 'climb', 'clinical', 'closely', 'clothing', 'club', 'cluster', 'coal', 'coast', 'coat', 'code', 'collapse', 'colleague', 'collect', 'collection', 'column', 'combination', 'combine', 'comedy', 'comfort', 'command', 'commercial', 'commission', 'commit', 'commitment', 'common', 'communicate', 'company', 'compare', 'comparison', 'compensation', 'compete', 'competition', 'competitive', 'competitor', 'complaint', 'complete', 'completely', 'complexity', 'complicate', 'component', 'compose', 'composition', 'compound', 'comprehensive', 'comprise', 'compromise', 'compute', 'concentrate', 'concentration', 'concert', 'conclude', 'conclusion', 'concrete', 'condition', 'conference', 'confidence', 'confirm', 'confusion', 'connect', 'consequence', 'consequently', 'conservative', 'consider', 'considerable', 'consideration', 'consist', 'consistent', 'constant', 'constantly', 'constitute', 'constraint', 'construct', 'construction', 'consult', 'consultant', 'consumer', 'contain', 'contemporary', 'content', 'contest', 'context', 'continuous', 'contract', 'contrast', 'contribute', 'contribution', 'control', 'controversial', 'convention', 'conventional', 'conversation', 'convert', 'cooperation', 'cope', 'core', 'corporate', 'corporation', 'correct',  ...
